# %% [markdown]
# # Statystyczne metody przetwarzania danych
#
# ## Laboratorium 2 - algorytm Najbliższego Sąsiada (NN)
#
#
# ### Opis
# Celem jest zbadanie danych i opracowanie algorytmu klasyfikacji liści. Do tego celu należy zaimplementować i zastosować klasyfikator najbliższego sąsiada - NN (Nearest Neighbor).
#
# Ukończony projekt powinien:
# * Klasyfikować dwie klasy liści:
#     * `Populus nigra` - klasa nr 3,
#     * `Quercus robur` - klasa nr 5.
#
# ### Zbiór danych
#
# Zbiór danych znajduje się w `dataset/dataset.npz`. Jest to zbiór danych pobrany i zmodyfikowany z adresu: <https://archive.ics.uci.edu/ml/datasets/leaf>.
#
# ### Przesyłanie zadań
#
# Wszystkie pliki należy spakować archiwizatorem **zip** i przesłać za pośrednictwem platformy WIKAMP. Poniżej oczekiwana zawartość archiwum:
#
# ```
# +-- 📂 [IMIE I NAZWISKO].zip
#     +-- 📜 Lab01.ipynb
#     +-- 📂 dataset
#         +-- 📜 dataset.npz
#         +-- 📜 ReadMe.pdf
# ```
#
# ### Zadanie 1
#
# Wczytaj dane z pliku `dataset.npz`. Plik ten zawiera zbiór danych podzielony na dwa podzbiory: treningowy `train` i testowy `test`. Każdy z nich zawiera cechy oraz indeksy klas. Dokładny opis zbioru danych znajduje się w pliku `ReadMe.pdf`.
#
# > Podpowiedź: Możesz wykorzystać poniższy kod:
# ```python
# with open('./dataset/dataset.npz', 'rb') as f:
#     data = np.load(f)
#     train, test = data['train'], data['test']
# ```

# %%
import numpy as np

with open('./dataset/dataset.npz', 'rb') as f:
    data = np.load(f)
    train, test = data['train'], data['test']

# %% [markdown]
# ### Zadanie 2
#
# Sprawdź:
# * ile jest wszystkich próbek z zbiorze,
# * ile jest próbek w poszczegónych klasach.
#
# Czy zauważyłeś jakieś problemy związane z tym zbiorem danych?

# %%
for i in range(1, 41):
    print('Probek w klasie:', i, sum(train[:, 0] == i))

print('')

# alternatywna opcja: vstring
for i in range(1, 41):
    print(f'probek w klasie {i} jest {sum(train[:, 0] == i)}')
# Out:
# Probek w klasie: 1 77
# Probek w klasie: 2 66
# Probek w klasie: 3 55
# Probek w klasie: 4 66
# Probek w klasie: 5 77
# Probek w klasie: 6 44
# Probek w klasie: 7 44
# Probek w klasie: 8 33
# Probek w klasie: 9 121
# Probek w klasie: 10 88
# Probek w klasie: 11 88
# Probek w klasie: 12 77
# Probek w klasie: 13 99
# Probek w klasie: 14 66
# Probek w klasie: 15 66
# Probek w klasie: 16 0
# Probek w klasie: 17 0
# Probek w klasie: 18 0
# Probek w klasie: 19 0
# Probek w klasie: 20 0
# Probek w klasie: 21 0
# Probek w klasie: 22 121
# Probek w klasie: 23 77
# Probek w klasie: 24 77
# Probek w klasie: 25 66
# Probek w klasie: 26 99
# Probek w klasie: 27 55
# Probek w klasie: 28 66
# Probek w klasie: 29 110
# Probek w klasie: 30 77
# Probek w klasie: 31 77
# Probek w klasie: 32 66
# Probek w klasie: 33 66
# Probek w klasie: 34 99
# Probek w klasie: 35 88
# Probek w klasie: 36 33
# Probek w klasie: 37 0
# Probek w klasie: 38 0
# Probek w klasie: 39 0
# Probek w klasie: 40 0
#
# probek w klasie 1 jest 77
# probek w klasie 2 jest 66
# probek w klasie 3 jest 55
# probek w klasie 4 jest 66
# probek w klasie 5 jest 77
# probek w klasie 6 jest 44
# probek w klasie 7 jest 44
# probek w klasie 8 jest 33
# probek w klasie 9 jest 121
# probek w klasie 10 jest 88
# probek w klasie 11 jest 88
# probek w klasie 12 jest 77
# probek w klasie 13 jest 99
# probek w klasie 14 jest 66
# probek w klasie 15 jest 66
# probek w klasie 16 jest 0
# probek w klasie 17 jest 0
# probek w klasie 18 jest 0
# probek w klasie 19 jest 0
# probek w klasie 20 jest 0
# probek w klasie 21 jest 0
# probek w klasie 22 jest 121
# probek w klasie 23 jest 77
# probek w klasie 24 jest 77
# probek w klasie 25 jest 66
# probek w klasie 26 jest 99
# probek w klasie 27 jest 55
# probek w klasie 28 jest 66
# probek w klasie 29 jest 110
# probek w klasie 30 jest 77
# probek w klasie 31 jest 77
# probek w klasie 32 jest 66
# probek w klasie 33 jest 66
# probek w klasie 34 jest 99
# probek w klasie 35 jest 88
# probek w klasie 36 jest 33
# probek w klasie 37 jest 0
# probek w klasie 38 jest 0
# probek w klasie 39 jest 0
# probek w klasie 40 jest 0

# %% [markdown]
# ### Zadanie 3
#
# Wybierz wiersze należące do poniższych klas (rodzaje liści) i zapisz w zmiennych `train_new` oraz `test_new`:
# * `Populus nigra` - klasa nr 3,
# * `Quercus robur` - klasa nr 5.
#
# Aby wybrać jedynie te wiersze, które należą do wymienionych klas, należy przefiltrować dane po kolumnie o indeksie `0`:

# %%
klasy = [3,5]

train_new = train[ np.isin(train[:, 0 ], klasy) ]
test_new = test[ np.isin(test[:, 0 ], klasy) ]

# albo tak
train_new = train[ (train[:, 0] == 3) | (train[:, 0] == 5) ]
test_new = test[ (test[:, 0] == 3) | (test[:, 0] == 5) ]

# %% [markdown]
# ### Zadanie 4
#
# A) Wybierz dwie dowolne cechy (*features*), np. o indeksach 4 i 8.<br />
# B) Przedstaw graficznie próbki - na osi X i Y wartości wybranych cech.
#
# Poniższy kod importuje moduł zawieracjący funkcje przydatne do wizualizacji danych z biblioteki `matplotlib` (*info: zwróć uwagę, że nadano alias `plt`*).
# ```python
# import matplotlib.pyplot as plt
# ```
#
# Możesz wykorzystać funkcje `plt.figure`, `plt.scatter`, `plt.legend`, `plt.title`, `plt.xlabel` i `plt.ylabel` w celu wykonania tego zadania.
#
# Scatter: <https://matplotlib.org/3.3.3/api/_as_gen/matplotlib.pyplot.scatter.html>
#
# >Ważne: Pamiętaj, że każdy przedstawiony wykres powinien być czytelny i posiadać następujące elementy:
# * tytuł,
# * opisy wszystkich osi,
# * legendę.
#
# > **Przykład**:
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
# plt.figure()
# plt.title("Próbki")
# plt.xlabel(f"Cecha 1")
# plt.ylabel(f"Cecha 2")
# samples = np.random.rand(2, 20, 2)
# samples[0] = samples[0]-0.5
# samples[1] = samples[1]+0.5
# for idx, sample in enumerate(samples): # iteracja po grupach
#     plt.scatter(x=sample[:, 0], y=sample[:, 1], label=idx)
# plt.legend()
# ```
# <img src="data:image/png;base64,..." />
#
# Dodatkowe zasoby:
# * `pyplot`: <https://matplotlib.org/tutorials/introductory/pyplot.html>

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure()
plt.title("Próbki")
plt.xlabel(f"Cecha 4")
plt.ylabel(f"Cecha 8")

for kl in [3, 5]:
    probki_kl = train[train[:, 0] == kl]
    x_kl = probki_kl[:, 4]
    y_kl = probki_kl[:, 8]
    plt.scatter(x_kl, y_kl, label=f'klasa {kl}')


# plt.scatter([1, 2, 3, 4], [5, 4, 3, 2])
# x_kl3 = probki_klasy_3[:, 4]
# y_kl3 = probki_klasy_3[:, 8]
# plt.scatter(x_kl3, y_kl3, label='klasa 3')

# x_kl5 = probki_klasy_5[:, 4]
# y_kl5 = probki_klasy_5[:, 8]
# plt.scatter(x_kl5, y_kl5, label='klasa 5')

plt.legend()

# %% [markdown]
# ### Zadanie 5
#
# Zaimplementuj funkcję `edist`, która zwróci _odległość Euklidesa_ pomiędzy punktem `x` oraz `y` uwzględniający wybrane cechy `features`.
#
# $$
# d(x, y) = \sqrt{\sum^{n-1}_{i=0}{(x_i - y_i)^2}}
# $$

# %%
features = [1, 2] # kolumny o indeksach 1, 2
x = [0, 2, 3]
y = [0, 5, 6]

def edist(x, y, features):
     return sum([(x[i] - y[i])**2 for i in features])**0.5

edist(x, y, features) # wynik: 4.242640687119285
# Out:
# 4.242640687119285

# %% [markdown]
# ### Zadanie 6
#
# Zaimplementuj klasyfikator najbliższego sąsiada.
# 1. Oblicz odległość każdego elementu ze zbioru _testowego_ do każdego elementu ze zbioru _treningowego_.
# 2. Odnajdź taki element ze zbioru _treningowego_, którego odległość do klasyfikowanego elementu (ze zbioru _testowego_) jest najmniejsza.
# 3. Przypisz klasyfikowanemu elementowi klasę.

# %%
def euclidean_distance(vec1, vec2):
    return np.sqrt(np.sum((vec1 - vec2) ** 2))

def nn_classifier(train, test):
    predicted_classes = []
    for test_sample in test:
        test_features = test_sample[1:]

        distances = []
        for train_sample in train:
            train_features = train_sample[1:]
            distance = euclidean_distance(test_features, train_features)
            distances.append((distance, train_sample[0]))

        nearest_neighbor_class = sorted(distances, key=lambda x: x[0])[0][1]
        predicted_classes.append(nearest_neighbor_class)
    
    return np.array(predicted_classes)

predicted_classes = nn_classifier(train, test)

for i, (true_class, predicted_class) in enumerate(zip(test[:, 0], predicted_classes)):
    print(f"Test sample {i + 1}: True class = {true_class}, Predicted class = {predicted_class}")
# Out:
# Test sample 1: True class = 31.0, Predicted class = 34.0
# Test sample 2: True class = 32.0, Predicted class = 26.0
# Test sample 3: True class = 31.0, Predicted class = 34.0
# Test sample 4: True class = 2.0, Predicted class = 32.0
# Test sample 5: True class = 30.0, Predicted class = 9.0
# Test sample 6: True class = 13.0, Predicted class = 24.0
# Test sample 7: True class = 28.0, Predicted class = 14.0
# Test sample 8: True class = 33.0, Predicted class = 3.0
# Test sample 9: True class = 9.0, Predicted class = 26.0
# Test sample 10: True class = 27.0, Predicted class = 9.0
# Test sample 11: True class = 3.0, Predicted class = 26.0
# Test sample 12: True class = 13.0, Predicted class = 30.0
# Test sample 13: True class = 33.0, Predicted class = 13.0
# Test sample 14: True class = 34.0, Predicted class = 34.0
# Test sample 15: True class = 31.0, Predicted class = 34.0
# Test sample 16: True class = 11.0, Predicted class = 11.0
# Test sample 17: True class = 8.0, Predicted class = 8.0
# Test sample 18: True class = 14.0, Predicted class = 28.0
# Test sample 19: True class = 10.0, Predicted class = 9.0
# Test sample 20: True class = 30.0, Predicted class = 26.0
# Test sample 21: True class = 34.0, Predicted class = 34.0
# Test sample 22: True class = 13.0, Predicted class = 33.0
# Test sample 23: True class = 30.0, Predicted class = 27.0
# Test sample 24: True class = 36.0, Predicted class = 15.0
# Test sample 25: True class = 6.0, Predicted class = 23.0
# Test sample 26: True class = 2.0, Predicted class = 27.0
# Test sample 27: True class = 11.0, Predicted class = 11.0
# Test sample 28: True class = 4.0, Predicted class = 27.0
# Test sample 29: True class = 33.0, Predicted class = 28.0
# Test sample 30: True class = 23.0, Predicted class = 9.0
# Test sample 31: True class = 26.0, Predicted class = 3.0
# Test sample 32: True class = 3.0, Predicted class = 13.0
# Test sample 33: True class = 36.0, Predicted class = 11.0
# Test sample 34: True class = 28.0, Predicted class = 22.0
# Test sample 35: True class = 8.0, Predicted class = 8.0
# Test sample 36: True class = 30.0, Predicted class = 33.0
# Test sample 37: True class = 26.0, Predicted class = 32.0
# Test sample 38: True class = 32.0, Predicted class = 22.0
# Test sample 39: True class = 27.0, Predicted class = 33.0
# Test sample 40: True class = 28.0, Predicted class = 35.0
# Test sample 41: True class = 27.0, Predicted class = 26.0
# Test sample 42: True class = 14.0, Predicted class = 35.0
# Test sample 43: True class = 9.0, Predicted class = 30.0
# Test sample 44: True class = 27.0, Predicted class = 2.0
# Test sample 45: True class = 7.0, Predicted class = 5.0
# Test sample 46: True class = 7.0, Predicted class = 33.0
# Test sample 47: True class = 8.0, Predicted class = 8.0
# Test sample 48: True class = 9.0, Predicted class = 25.0
# Test sample 49: True class = 28.0, Predicted class = 12.0
# Test sample 50: True class = 32.0, Predicted class = 29.0
# Test sample 51: True class = 24.0, Predicted class = 33.0
# Test sample 52: True class = 6.0, Predicted class = 11.0
# Test sample 53: True class = 15.0, Predicted class = 10.0
# Test sample 54: True class = 10.0, Predicted class = 30.0
# Test sample 55: True class = 24.0, Predicted class = 13.0
# Test sample 56: True class = 1.0, Predicted class = 29.0
# Test sample 57: True class = 14.0, Predicted class = 35.0
# Test sample 58: True class = 13.0, Predicted class = 24.0
# Test sample 59: True class = 8.0, Predicted class = 31.0
# Test sample 60: True class = 23.0, Predicted class = 29.0
# Test sample 61: True class = 32.0, Predicted class = 13.0
# Test sample 62: True class = 31.0, Predicted class = 34.0
# Test sample 63: True class = 32.0, Predicted class = 27.0
# Test sample 64: True class = 10.0, Predicted class = 30.0
# Test sample 65: True class = 25.0, Predicted class = 30.0
# Test sample 66: True class = 14.0, Predicted class = 32.0
# Test sample 67: True class = 12.0, Predicted class = 7.0
# Test sample 68: True class = 6.0, Predicted class = 11.0
# Test sample 69: True class = 5.0, Predicted class = 30.0
# Test sample 70: True class = 4.0, Predicted class = 24.0
# Test sample 71: True class = 15.0, Predicted class = 10.0
# Test sample 72: True class = 11.0, Predicted class = 11.0
# Test sample 73: True class = 12.0, Predicted class = 5.0
# Test sample 74: True class = 1.0, Predicted class = 29.0
# Test sample 75: True class = 2.0, Predicted class = 22.0
# Test sample 76: True class = 5.0, Predicted class = 22.0
# Test sample 77: True class = 5.0, Predicted class = 32.0
# Test sample 78: True class = 30.0, Predicted class = 9.0
# Test sample 79: True class = 12.0, Predicted class = 32.0
# Test sample 80: True class = 8.0, Predicted class = 31.0
# Test sample 81: True class = 3.0, Predicted class = 13.0
# Test sample 82: True class = 15.0, Predicted class = 30.0
# Test sample 83: True class = 11.0, Predicted class = 9.0
# Test sample 84: True class = 24.0, Predicted class = 26.0
# Test sample 85: True class = 26.0, Predicted class = 32.0
# Test sample 86: True class = 36.0, Predicted class = 15.0
# Test sample 87: True class = 3.0, Predicted class = 24.0
# Test sample 88: True class = 7.0, Predicted class = 2.0
# Test sample 89: True class = 33.0, Predicted class = 35.0
# Test sample 90: True class = 7.0, Predicted class = 32.0
# Test sample 91: True class = 24.0, Predicted class = 1.0
# Test sample 92: True class = 28.0, Predicted class = 12.0
# Test sample 93: True class = 36.0, Predicted class = 15.0
# Test sample 94: True class = 11.0, Predicted class = 11.0
# Test sample 95: True class = 25.0, Predicted class = 9.0
# Test sample 96: True class = 15.0, Predicted class = 15.0
# Test sample 97: True class = 35.0, Predicted class = 14.0
# Test sample 98: True class = 7.0, Predicted class = 32.0
# Test sample 99: True class = 10.0, Predicted class = 4.0
# Test sample 100: True class = 11.0, Predicted class = 11.0
# Test sample 101: True class = 29.0, Predicted class = 26.0
# Test sample 102: True class = 14.0, Predicted class = 28.0
# Test sample 103: True class = 35.0, Predicted class = 32.0
# Test sample 104: True class = 24.0, Predicted class = 30.0
# Test sample 105: True class = 6.0, Predicted class = 9.0
# Test sample 106: True class = 27.0, Predicted class = 4.0
# Test sample 107: True class = 5.0, Predicted class = 7.0
# Test sample 108: True class = 1.0, Predicted class = 29.0
# Test sample 109: True class = 5.0, Predicted class = 7.0
# Test sample 110: True class = 29.0, Predicted class = 1.0
# Test sample 111: True class = 12.0, Predicted class = 14.0
# Test sample 112: True class = 12.0, Predicted class = 28.0
# Test sample 113: True class = 24.0, Predicted class = 4.0
# Test sample 114: True class = 33.0, Predicted class = 13.0
# Test sample 115: True class = 10.0, Predicted class = 9.0
# Test sample 116: True class = 8.0, Predicted class = 8.0
# Test sample 117: True class = 22.0, Predicted class = 32.0
# Test sample 118: True class = 27.0, Predicted class = 4.0
# Test sample 119: True class = 8.0, Predicted class = 8.0
# Test sample 120: True class = 1.0, Predicted class = 32.0
# Test sample 121: True class = 23.0, Predicted class = 23.0
# Test sample 122: True class = 36.0, Predicted class = 15.0
# Test sample 123: True class = 28.0, Predicted class = 25.0
# Test sample 124: True class = 14.0, Predicted class = 27.0
# Test sample 125: True class = 11.0, Predicted class = 6.0
# Test sample 126: True class = 3.0, Predicted class = 1.0
# Test sample 127: True class = 23.0, Predicted class = 29.0
# Test sample 128: True class = 36.0, Predicted class = 15.0
# Test sample 129: True class = 25.0, Predicted class = 10.0
# Test sample 130: True class = 35.0, Predicted class = 2.0
# Test sample 131: True class = 1.0, Predicted class = 13.0
# Test sample 132: True class = 36.0, Predicted class = 10.0
# Test sample 133: True class = 11.0, Predicted class = 11.0
# Test sample 134: True class = 8.0, Predicted class = 8.0
# Test sample 135: True class = 7.0, Predicted class = 9.0
# Test sample 136: True class = 2.0, Predicted class = 32.0
# Test sample 137: True class = 31.0, Predicted class = 34.0
# Test sample 138: True class = 32.0, Predicted class = 26.0
# Test sample 139: True class = 31.0, Predicted class = 34.0
# Test sample 140: True class = 2.0, Predicted class = 32.0
# Test sample 141: True class = 30.0, Predicted class = 9.0
# Test sample 142: True class = 13.0, Predicted class = 24.0
# Test sample 143: True class = 28.0, Predicted class = 2.0
# Test sample 144: True class = 33.0, Predicted class = 3.0
# Test sample 145: True class = 9.0, Predicted class = 24.0
# Test sample 146: True class = 27.0, Predicted class = 26.0
# Test sample 147: True class = 3.0, Predicted class = 26.0
# Test sample 148: True class = 13.0, Predicted class = 30.0
# Test sample 149: True class = 33.0, Predicted class = 4.0
# Test sample 150: True class = 34.0, Predicted class = 31.0
# Test sample 151: True class = 31.0, Predicted class = 34.0
# Test sample 152: True class = 11.0, Predicted class = 11.0
# Test sample 153: True class = 8.0, Predicted class = 8.0
# Test sample 154: True class = 14.0, Predicted class = 28.0
# Test sample 155: True class = 10.0, Predicted class = 9.0
# Test sample 156: True class = 30.0, Predicted class = 26.0
# Test sample 157: True class = 34.0, Predicted class = 34.0
# Test sample 158: True class = 13.0, Predicted class = 33.0
# Test sample 159: True class = 30.0, Predicted class = 4.0
# Test sample 160: True class = 36.0, Predicted class = 15.0
# Test sample 161: True class = 6.0, Predicted class = 23.0
# Test sample 162: True class = 2.0, Predicted class = 27.0
# Test sample 163: True class = 11.0, Predicted class = 11.0
# Test sample 164: True class = 4.0, Predicted class = 27.0
# Test sample 165: True class = 33.0, Predicted class = 28.0
# Test sample 166: True class = 23.0, Predicted class = 9.0
# Test sample 167: True class = 26.0, Predicted class = 3.0
# Test sample 168: True class = 3.0, Predicted class = 26.0
# Test sample 169: True class = 36.0, Predicted class = 11.0
# Test sample 170: True class = 28.0, Predicted class = 22.0
# Test sample 171: True class = 8.0, Predicted class = 8.0
# Test sample 172: True class = 30.0, Predicted class = 10.0
# Test sample 173: True class = 26.0, Predicted class = 1.0
# Test sample 174: True class = 32.0, Predicted class = 22.0
# Test sample 175: True class = 27.0, Predicted class = 33.0
# Test sample 176: True class = 28.0, Predicted class = 35.0
# Test sample 177: True class = 27.0, Predicted class = 26.0
# Test sample 178: True class = 14.0, Predicted class = 35.0
# Test sample 179: True class = 9.0, Predicted class = 30.0
# Test sample 180: True class = 27.0, Predicted class = 13.0
# Test sample 181: True class = 7.0, Predicted class = 5.0
# Test sample 182: True class = 7.0, Predicted class = 32.0
# Test sample 183: True class = 8.0, Predicted class = 8.0
# Test sample 184: True class = 9.0, Predicted class = 25.0
# Test sample 185: True class = 28.0, Predicted class = 12.0
# Test sample 186: True class = 32.0, Predicted class = 29.0
# Test sample 187: True class = 24.0, Predicted class = 3.0
# Test sample 188: True class = 6.0, Predicted class = 11.0
# Test sample 189: True class = 15.0, Predicted class = 10.0
# Test sample 190: True class = 10.0, Predicted class = 30.0
# Test sample 191: True class = 24.0, Predicted class = 13.0
# Test sample 192: True class = 1.0, Predicted class = 29.0
# Test sample 193: True class = 14.0, Predicted class = 35.0
# Test sample 194: True class = 13.0, Predicted class = 30.0
# Test sample 195: True class = 8.0, Predicted class = 31.0
# Test sample 196: True class = 23.0, Predicted class = 24.0
# Test sample 197: True class = 32.0, Predicted class = 1.0
# Test sample 198: True class = 31.0, Predicted class = 34.0
# Test sample 199: True class = 32.0, Predicted class = 27.0
# Test sample 200: True class = 10.0, Predicted class = 30.0
# Test sample 201: True class = 25.0, Predicted class = 30.0
# Test sample 202: True class = 14.0, Predicted class = 32.0
# Test sample 203: True class = 12.0, Predicted class = 28.0
# Test sample 204: True class = 6.0, Predicted class = 11.0
# Test sample 205: True class = 5.0, Predicted class = 30.0
# Test sample 206: True class = 4.0, Predicted class = 26.0
# Test sample 207: True class = 15.0, Predicted class = 10.0
# Test sample 208: True class = 11.0, Predicted class = 11.0
# Test sample 209: True class = 12.0, Predicted class = 28.0
# Test sample 210: True class = 1.0, Predicted class = 29.0
# Test sample 211: True class = 2.0, Predicted class = 22.0
# Test sample 212: True class = 5.0, Predicted class = 22.0
# Test sample 213: True class = 5.0, Predicted class = 9.0
# Test sample 214: True class = 30.0, Predicted class = 9.0
# Test sample 215: True class = 12.0, Predicted class = 32.0
# Test sample 216: True class = 8.0, Predicted class = 31.0
# Test sample 217: True class = 3.0, Predicted class = 32.0
# Test sample 218: True class = 15.0, Predicted class = 15.0
# Test sample 219: True class = 11.0, Predicted class = 9.0
# Test sample 220: True class = 24.0, Predicted class = 26.0
# Test sample 221: True class = 26.0, Predicted class = 22.0
# Test sample 222: True class = 36.0, Predicted class = 15.0
# Test sample 223: True class = 3.0, Predicted class = 33.0
# Test sample 224: True class = 7.0, Predicted class = 32.0
# Test sample 225: True class = 33.0, Predicted class = 12.0
# Test sample 226: True class = 7.0, Predicted class = 27.0
# Test sample 227: True class = 24.0, Predicted class = 23.0
# Test sample 228: True class = 28.0, Predicted class = 12.0
# Test sample 229: True class = 36.0, Predicted class = 15.0
# Test sample 230: True class = 11.0, Predicted class = 11.0
# Test sample 231: True class = 25.0, Predicted class = 9.0
# Test sample 232: True class = 15.0, Predicted class = 15.0
# Test sample 233: True class = 35.0, Predicted class = 14.0
# Test sample 234: True class = 7.0, Predicted class = 1.0
# Test sample 235: True class = 10.0, Predicted class = 4.0
# Test sample 236: True class = 11.0, Predicted class = 11.0
# Test sample 237: True class = 29.0, Predicted class = 26.0
# Test sample 238: True class = 14.0, Predicted class = 28.0
# Test sample 239: True class = 35.0, Predicted class = 28.0
# Test sample 240: True class = 24.0, Predicted class = 30.0
# Test sample 241: True class = 6.0, Predicted class = 9.0
# Test sample 242: True class = 27.0, Predicted class = 4.0
# Test sample 243: True class = 5.0, Predicted class = 7.0
# Test sample 244: True class = 1.0, Predicted class = 29.0
# Test sample 245: True class = 5.0, Predicted class = 7.0
# Test sample 246: True class = 29.0, Predicted class = 1.0
# Test sample 247: True class = 12.0, Predicted class = 14.0
# Test sample 248: True class = 12.0, Predicted class = 30.0
# Test sample 249: True class = 24.0, Predicted class = 4.0
# Test sample 250: True class = 33.0, Predicted class = 27.0
# Test sample 251: True class = 10.0, Predicted class = 9.0
# Test sample 252: True class = 8.0, Predicted class = 8.0
# Test sample 253: True class = 22.0, Predicted class = 32.0
# Test sample 254: True class = 27.0, Predicted class = 13.0
# Test sample 255: True class = 8.0, Predicted class = 8.0
# Test sample 256: True class = 1.0, Predicted class = 24.0
# Test sample 257: True class = 23.0, Predicted class = 23.0
# Test sample 258: True class = 36.0, Predicted class = 15.0
# Test sample 259: True class = 28.0, Predicted class = 25.0
# Test sample 260: True class = 14.0, Predicted class = 27.0
# Test sample 261: True class = 11.0, Predicted class = 6.0
# Test sample 262: True class = 3.0, Predicted class = 23.0
# Test sample 263: True class = 23.0, Predicted class = 9.0
# Test sample 264: True class = 36.0, Predicted class = 15.0
# Test sample 265: True class = 25.0, Predicted class = 10.0
# Test sample 266: True class = 35.0, Predicted class = 2.0
# Test sample 267: True class = 1.0, Predicted class = 33.0
# Test sample 268: True class = 36.0, Predicted class = 10.0
# Test sample 269: True class = 11.0, Predicted class = 11.0
# Test sample 270: True class = 8.0, Predicted class = 8.0
# Test sample 271: True class = 7.0, Predicted class = 9.0
# Test sample 272: True class = 2.0, Predicted class = 32.0
# Test sample 273: True class = 31.0, Predicted class = 34.0
# Test sample 274: True class = 32.0, Predicted class = 2.0
# Test sample 275: True class = 31.0, Predicted class = 34.0
# Test sample 276: True class = 2.0, Predicted class = 32.0
# Test sample 277: True class = 30.0, Predicted class = 9.0
# Test sample 278: True class = 13.0, Predicted class = 3.0
# Test sample 279: True class = 28.0, Predicted class = 14.0
# Test sample 280: True class = 33.0, Predicted class = 3.0
# Test sample 281: True class = 9.0, Predicted class = 26.0
# Test sample 282: True class = 27.0, Predicted class = 9.0
# Test sample 283: True class = 3.0, Predicted class = 4.0
# Test sample 284: True class = 13.0, Predicted class = 30.0
# Test sample 285: True class = 33.0, Predicted class = 13.0
# Test sample 286: True class = 34.0, Predicted class = 34.0
# Test sample 287: True class = 31.0, Predicted class = 34.0
# Test sample 288: True class = 11.0, Predicted class = 11.0
# Test sample 289: True class = 8.0, Predicted class = 8.0
# Test sample 290: True class = 14.0, Predicted class = 28.0
# Test sample 291: True class = 10.0, Predicted class = 9.0
# Test sample 292: True class = 30.0, Predicted class = 26.0
# Test sample 293: True class = 34.0, Predicted class = 34.0
# Test sample 294: True class = 13.0, Predicted class = 33.0
# Test sample 295: True class = 30.0, Predicted class = 27.0
# Test sample 296: True class = 36.0, Predicted class = 15.0
# Test sample 297: True class = 6.0, Predicted class = 23.0
# Test sample 298: True class = 2.0, Predicted class = 5.0
# Test sample 299: True class = 11.0, Predicted class = 11.0
# Test sample 300: True class = 4.0, Predicted class = 27.0
# Test sample 301: True class = 33.0, Predicted class = 30.0
# Test sample 302: True class = 23.0, Predicted class = 3.0
# Test sample 303: True class = 26.0, Predicted class = 3.0
# Test sample 304: True class = 3.0, Predicted class = 26.0
# Test sample 305: True class = 36.0, Predicted class = 11.0
# Test sample 306: True class = 28.0, Predicted class = 22.0
# Test sample 307: True class = 8.0, Predicted class = 8.0
# Test sample 308: True class = 30.0, Predicted class = 33.0
# Test sample 309: True class = 26.0, Predicted class = 32.0
# Test sample 310: True class = 32.0, Predicted class = 22.0
# Test sample 311: True class = 27.0, Predicted class = 33.0
# Test sample 312: True class = 28.0, Predicted class = 35.0
# Test sample 313: True class = 27.0, Predicted class = 26.0
# Test sample 314: True class = 14.0, Predicted class = 27.0
# Test sample 315: True class = 9.0, Predicted class = 30.0
# Test sample 316: True class = 27.0, Predicted class = 13.0
# Test sample 317: True class = 7.0, Predicted class = 5.0
# Test sample 318: True class = 7.0, Predicted class = 32.0
# Test sample 319: True class = 8.0, Predicted class = 8.0
# Test sample 320: True class = 9.0, Predicted class = 25.0
# Test sample 321: True class = 28.0, Predicted class = 12.0
# Test sample 322: True class = 32.0, Predicted class = 29.0
# Test sample 323: True class = 24.0, Predicted class = 33.0
# Test sample 324: True class = 6.0, Predicted class = 11.0
# Test sample 325: True class = 15.0, Predicted class = 10.0
# Test sample 326: True class = 10.0, Predicted class = 30.0
# Test sample 327: True class = 24.0, Predicted class = 13.0
# Test sample 328: True class = 1.0, Predicted class = 29.0
# Test sample 329: True class = 14.0, Predicted class = 12.0
# Test sample 330: True class = 13.0, Predicted class = 24.0
# Test sample 331: True class = 8.0, Predicted class = 31.0
# Test sample 332: True class = 23.0, Predicted class = 29.0
# Test sample 333: True class = 32.0, Predicted class = 13.0
# Test sample 334: True class = 31.0, Predicted class = 34.0
# Test sample 335: True class = 32.0, Predicted class = 27.0
# Test sample 336: True class = 10.0, Predicted class = 4.0
# Test sample 337: True class = 25.0, Predicted class = 28.0
# Test sample 338: True class = 14.0, Predicted class = 32.0
# Test sample 339: True class = 12.0, Predicted class = 7.0
# Test sample 340: True class = 6.0, Predicted class = 11.0
# Test sample 341: True class = 5.0, Predicted class = 30.0
# Test sample 342: True class = 4.0, Predicted class = 24.0
# Test sample 343: True class = 15.0, Predicted class = 10.0
# Test sample 344: True class = 11.0, Predicted class = 11.0
# Test sample 345: True class = 12.0, Predicted class = 5.0
# Test sample 346: True class = 1.0, Predicted class = 29.0
# Test sample 347: True class = 2.0, Predicted class = 13.0
# Test sample 348: True class = 5.0, Predicted class = 22.0
# Test sample 349: True class = 5.0, Predicted class = 32.0
# Test sample 350: True class = 30.0, Predicted class = 9.0
# Test sample 351: True class = 12.0, Predicted class = 32.0
# Test sample 352: True class = 8.0, Predicted class = 12.0
# Test sample 353: True class = 3.0, Predicted class = 32.0
# Test sample 354: True class = 15.0, Predicted class = 30.0
# Test sample 355: True class = 11.0, Predicted class = 9.0
# Test sample 356: True class = 24.0, Predicted class = 13.0
# Test sample 357: True class = 26.0, Predicted class = 32.0
# Test sample 358: True class = 36.0, Predicted class = 15.0
# Test sample 359: True class = 3.0, Predicted class = 13.0
# Test sample 360: True class = 7.0, Predicted class = 2.0
# Test sample 361: True class = 33.0, Predicted class = 35.0
# Test sample 362: True class = 7.0, Predicted class = 32.0
# Test sample 363: True class = 24.0, Predicted class = 23.0
# Test sample 364: True class = 28.0, Predicted class = 22.0
# Test sample 365: True class = 36.0, Predicted class = 15.0
# Test sample 366: True class = 11.0, Predicted class = 11.0
# Test sample 367: True class = 25.0, Predicted class = 10.0
# Test sample 368: True class = 15.0, Predicted class = 15.0
# Test sample 369: True class = 35.0, Predicted class = 12.0
# Test sample 370: True class = 7.0, Predicted class = 32.0
# Test sample 371: True class = 10.0, Predicted class = 4.0
# Test sample 372: True class = 11.0, Predicted class = 11.0
# Test sample 373: True class = 29.0, Predicted class = 26.0
# Test sample 374: True class = 14.0, Predicted class = 28.0
# Test sample 375: True class = 35.0, Predicted class = 32.0
# Test sample 376: True class = 24.0, Predicted class = 30.0
# Test sample 377: True class = 6.0, Predicted class = 9.0
# Test sample 378: True class = 27.0, Predicted class = 4.0
# Test sample 379: True class = 5.0, Predicted class = 4.0
# Test sample 380: True class = 1.0, Predicted class = 29.0
# Test sample 381: True class = 5.0, Predicted class = 7.0
# Test sample 382: True class = 29.0, Predicted class = 22.0
# Test sample 383: True class = 12.0, Predicted class = 14.0
# Test sample 384: True class = 12.0, Predicted class = 35.0
# Test sample 385: True class = 24.0, Predicted class = 27.0
# Test sample 386: True class = 33.0, Predicted class = 13.0
# Test sample 387: True class = 10.0, Predicted class = 9.0
# Test sample 388: True class = 8.0, Predicted class = 8.0
# Test sample 389: True class = 22.0, Predicted class = 32.0
# Test sample 390: True class = 27.0, Predicted class = 4.0
# Test sample 391: True class = 8.0, Predicted class = 8.0
# Test sample 392: True class = 1.0, Predicted class = 32.0
# Test sample 393: True class = 23.0, Predicted class = 23.0
# Test sample 394: True class = 36.0, Predicted class = 15.0
# Test sample 395: True class = 28.0, Predicted class = 25.0
# Test sample 396: True class = 14.0, Predicted class = 27.0
# Test sample 397: True class = 11.0, Predicted class = 6.0
# Test sample 398: True class = 3.0, Predicted class = 1.0
# Test sample 399: True class = 23.0, Predicted class = 29.0
# Test sample 400: True class = 36.0, Predicted class = 15.0
# Test sample 401: True class = 25.0, Predicted class = 10.0
# Test sample 402: True class = 35.0, Predicted class = 2.0
# Test sample 403: True class = 1.0, Predicted class = 13.0
# Test sample 404: True class = 36.0, Predicted class = 10.0
# Test sample 405: True class = 11.0, Predicted class = 11.0
# Test sample 406: True class = 8.0, Predicted class = 8.0
# Test sample 407: True class = 7.0, Predicted class = 5.0
# Test sample 408: True class = 2.0, Predicted class = 32.0
# Test sample 409: True class = 31.0, Predicted class = 34.0
# Test sample 410: True class = 32.0, Predicted class = 26.0
# Test sample 411: True class = 31.0, Predicted class = 34.0
# Test sample 412: True class = 2.0, Predicted class = 13.0
# Test sample 413: True class = 30.0, Predicted class = 9.0
# Test sample 414: True class = 13.0, Predicted class = 3.0
# Test sample 415: True class = 28.0, Predicted class = 2.0
# Test sample 416: True class = 33.0, Predicted class = 30.0
# Test sample 417: True class = 9.0, Predicted class = 26.0
# Test sample 418: True class = 27.0, Predicted class = 9.0
# Test sample 419: True class = 3.0, Predicted class = 13.0
# Test sample 420: True class = 13.0, Predicted class = 30.0
# Test sample 421: True class = 33.0, Predicted class = 13.0
# Test sample 422: True class = 34.0, Predicted class = 34.0
# Test sample 423: True class = 31.0, Predicted class = 34.0
# Test sample 424: True class = 11.0, Predicted class = 11.0
# Test sample 425: True class = 8.0, Predicted class = 8.0
# Test sample 426: True class = 14.0, Predicted class = 28.0
# Test sample 427: True class = 10.0, Predicted class = 3.0
# Test sample 428: True class = 30.0, Predicted class = 26.0
# Test sample 429: True class = 34.0, Predicted class = 34.0
# Test sample 430: True class = 13.0, Predicted class = 1.0
# Test sample 431: True class = 30.0, Predicted class = 33.0
# Test sample 432: True class = 36.0, Predicted class = 15.0
# Test sample 433: True class = 6.0, Predicted class = 23.0
# Test sample 434: True class = 2.0, Predicted class = 27.0
# Test sample 435: True class = 11.0, Predicted class = 11.0
# Test sample 436: True class = 4.0, Predicted class = 27.0
# Test sample 437: True class = 33.0, Predicted class = 28.0
# Test sample 438: True class = 23.0, Predicted class = 24.0
# Test sample 439: True class = 26.0, Predicted class = 3.0
# Test sample 440: True class = 3.0, Predicted class = 26.0
# Test sample 441: True class = 36.0, Predicted class = 11.0
# Test sample 442: True class = 28.0, Predicted class = 22.0
# Test sample 443: True class = 8.0, Predicted class = 8.0
# Test sample 444: True class = 30.0, Predicted class = 33.0
# Test sample 445: True class = 26.0, Predicted class = 32.0
# Test sample 446: True class = 32.0, Predicted class = 22.0
# Test sample 447: True class = 27.0, Predicted class = 33.0
# Test sample 448: True class = 28.0, Predicted class = 35.0
# Test sample 449: True class = 27.0, Predicted class = 23.0
# Test sample 450: True class = 14.0, Predicted class = 27.0
# Test sample 451: True class = 9.0, Predicted class = 15.0
# Test sample 452: True class = 27.0, Predicted class = 13.0
# Test sample 453: True class = 7.0, Predicted class = 5.0
# Test sample 454: True class = 7.0, Predicted class = 33.0
# Test sample 455: True class = 8.0, Predicted class = 8.0
# Test sample 456: True class = 9.0, Predicted class = 4.0
# Test sample 457: True class = 28.0, Predicted class = 12.0
# Test sample 458: True class = 32.0, Predicted class = 9.0
# Test sample 459: True class = 24.0, Predicted class = 33.0
# Test sample 460: True class = 6.0, Predicted class = 11.0
# Test sample 461: True class = 15.0, Predicted class = 10.0
# Test sample 462: True class = 10.0, Predicted class = 30.0
# Test sample 463: True class = 24.0, Predicted class = 13.0
# Test sample 464: True class = 1.0, Predicted class = 29.0
# Test sample 465: True class = 14.0, Predicted class = 35.0
# Test sample 466: True class = 13.0, Predicted class = 24.0
# Test sample 467: True class = 8.0, Predicted class = 31.0
# Test sample 468: True class = 23.0, Predicted class = 29.0
# Test sample 469: True class = 32.0, Predicted class = 22.0
# Test sample 470: True class = 31.0, Predicted class = 34.0
# Test sample 471: True class = 32.0, Predicted class = 27.0
# Test sample 472: True class = 10.0, Predicted class = 30.0
# Test sample 473: True class = 25.0, Predicted class = 28.0
# Test sample 474: True class = 14.0, Predicted class = 32.0
# Test sample 475: True class = 12.0, Predicted class = 7.0
# Test sample 476: True class = 6.0, Predicted class = 11.0
# Test sample 477: True class = 5.0, Predicted class = 30.0
# Test sample 478: True class = 4.0, Predicted class = 24.0
# Test sample 479: True class = 15.0, Predicted class = 10.0
# Test sample 480: True class = 11.0, Predicted class = 11.0
# Test sample 481: True class = 12.0, Predicted class = 28.0
# Test sample 482: True class = 1.0, Predicted class = 29.0
# Test sample 483: True class = 2.0, Predicted class = 22.0
# Test sample 484: True class = 5.0, Predicted class = 22.0
# Test sample 485: True class = 5.0, Predicted class = 9.0
# Test sample 486: True class = 30.0, Predicted class = 9.0
# Test sample 487: True class = 12.0, Predicted class = 32.0
# Test sample 488: True class = 8.0, Predicted class = 31.0
# Test sample 489: True class = 3.0, Predicted class = 13.0
# Test sample 490: True class = 15.0, Predicted class = 15.0
# Test sample 491: True class = 11.0, Predicted class = 9.0
# Test sample 492: True class = 24.0, Predicted class = 13.0
# Test sample 493: True class = 26.0, Predicted class = 22.0
# Test sample 494: True class = 36.0, Predicted class = 15.0
# Test sample 495: True class = 3.0, Predicted class = 24.0
# Test sample 496: True class = 7.0, Predicted class = 32.0
# Test sample 497: True class = 33.0, Predicted class = 25.0
# Test sample 498: True class = 7.0, Predicted class = 32.0
# Test sample 499: True class = 24.0, Predicted class = 23.0
# Test sample 500: True class = 28.0, Predicted class = 14.0
# Test sample 501: True class = 36.0, Predicted class = 15.0
# Test sample 502: True class = 11.0, Predicted class = 11.0
# Test sample 503: True class = 25.0, Predicted class = 9.0
# Test sample 504: True class = 15.0, Predicted class = 15.0
# Test sample 505: True class = 35.0, Predicted class = 14.0
# Test sample 506: True class = 7.0, Predicted class = 32.0
# Test sample 507: True class = 10.0, Predicted class = 4.0
# Test sample 508: True class = 11.0, Predicted class = 11.0
# Test sample 509: True class = 29.0, Predicted class = 22.0
# Test sample 510: True class = 14.0, Predicted class = 28.0
# Test sample 511: True class = 35.0, Predicted class = 28.0
# Test sample 512: True class = 24.0, Predicted class = 30.0
# Test sample 513: True class = 6.0, Predicted class = 6.0
# Test sample 514: True class = 27.0, Predicted class = 4.0
# Test sample 515: True class = 5.0, Predicted class = 7.0
# Test sample 516: True class = 1.0, Predicted class = 29.0
# Test sample 517: True class = 5.0, Predicted class = 7.0
# Test sample 518: True class = 29.0, Predicted class = 1.0
# Test sample 519: True class = 12.0, Predicted class = 22.0
# Test sample 520: True class = 12.0, Predicted class = 28.0
# Test sample 521: True class = 24.0, Predicted class = 4.0
# Test sample 522: True class = 33.0, Predicted class = 13.0
# Test sample 523: True class = 10.0, Predicted class = 9.0
# Test sample 524: True class = 8.0, Predicted class = 8.0
# Test sample 525: True class = 22.0, Predicted class = 32.0
# Test sample 526: True class = 27.0, Predicted class = 13.0
# Test sample 527: True class = 8.0, Predicted class = 8.0
# Test sample 528: True class = 1.0, Predicted class = 32.0
# Test sample 529: True class = 23.0, Predicted class = 23.0
# Test sample 530: True class = 36.0, Predicted class = 10.0
# Test sample 531: True class = 28.0, Predicted class = 25.0
# Test sample 532: True class = 14.0, Predicted class = 27.0
# Test sample 533: True class = 11.0, Predicted class = 6.0
# Test sample 534: True class = 3.0, Predicted class = 1.0
# Test sample 535: True class = 23.0, Predicted class = 29.0
# Test sample 536: True class = 36.0, Predicted class = 15.0
# Test sample 537: True class = 25.0, Predicted class = 10.0
# Test sample 538: True class = 35.0, Predicted class = 2.0
# Test sample 539: True class = 1.0, Predicted class = 33.0
# Test sample 540: True class = 36.0, Predicted class = 10.0
# Test sample 541: True class = 11.0, Predicted class = 11.0
# Test sample 542: True class = 8.0, Predicted class = 8.0
# Test sample 543: True class = 7.0, Predicted class = 5.0
# Test sample 544: True class = 2.0, Predicted class = 32.0
# Test sample 545: True class = 31.0, Predicted class = 34.0
# Test sample 546: True class = 32.0, Predicted class = 2.0
# Test sample 547: True class = 31.0, Predicted class = 34.0
# Test sample 548: True class = 2.0, Predicted class = 7.0
# Test sample 549: True class = 30.0, Predicted class = 9.0
# Test sample 550: True class = 13.0, Predicted class = 24.0
# Test sample 551: True class = 28.0, Predicted class = 12.0
# Test sample 552: True class = 33.0, Predicted class = 30.0
# Test sample 553: True class = 9.0, Predicted class = 26.0
# Test sample 554: True class = 27.0, Predicted class = 9.0
# Test sample 555: True class = 3.0, Predicted class = 26.0
# Test sample 556: True class = 13.0, Predicted class = 30.0
# Test sample 557: True class = 33.0, Predicted class = 13.0
# Test sample 558: True class = 34.0, Predicted class = 34.0
# Test sample 559: True class = 31.0, Predicted class = 34.0
# Test sample 560: True class = 11.0, Predicted class = 11.0
# Test sample 561: True class = 8.0, Predicted class = 8.0
# Test sample 562: True class = 14.0, Predicted class = 28.0
# Test sample 563: True class = 10.0, Predicted class = 9.0
# Test sample 564: True class = 30.0, Predicted class = 26.0
# Test sample 565: True class = 34.0, Predicted class = 34.0
# Test sample 566: True class = 13.0, Predicted class = 3.0
# Test sample 567: True class = 30.0, Predicted class = 27.0
# Test sample 568: True class = 36.0, Predicted class = 15.0
# Test sample 569: True class = 6.0, Predicted class = 23.0
# Test sample 570: True class = 2.0, Predicted class = 5.0
# Test sample 571: True class = 11.0, Predicted class = 11.0
# Test sample 572: True class = 4.0, Predicted class = 27.0
# Test sample 573: True class = 33.0, Predicted class = 28.0
# Test sample 574: True class = 23.0, Predicted class = 24.0
# Test sample 575: True class = 26.0, Predicted class = 3.0
# Test sample 576: True class = 3.0, Predicted class = 13.0
# Test sample 577: True class = 36.0, Predicted class = 11.0
# Test sample 578: True class = 28.0, Predicted class = 22.0
# Test sample 579: True class = 8.0, Predicted class = 8.0
# Test sample 580: True class = 30.0, Predicted class = 33.0
# Test sample 581: True class = 26.0, Predicted class = 32.0
# Test sample 582: True class = 32.0, Predicted class = 29.0
# Test sample 583: True class = 27.0, Predicted class = 33.0
# Test sample 584: True class = 28.0, Predicted class = 35.0
# Test sample 585: True class = 27.0, Predicted class = 26.0
# Test sample 586: True class = 14.0, Predicted class = 27.0
# Test sample 587: True class = 9.0, Predicted class = 30.0
# Test sample 588: True class = 27.0, Predicted class = 2.0
# Test sample 589: True class = 7.0, Predicted class = 5.0
# Test sample 590: True class = 7.0, Predicted class = 32.0
# Test sample 591: True class = 8.0, Predicted class = 8.0
# Test sample 592: True class = 9.0, Predicted class = 25.0
# Test sample 593: True class = 28.0, Predicted class = 12.0
# Test sample 594: True class = 32.0, Predicted class = 29.0
# Test sample 595: True class = 24.0, Predicted class = 33.0
# Test sample 596: True class = 6.0, Predicted class = 11.0
# Test sample 597: True class = 15.0, Predicted class = 10.0
# Test sample 598: True class = 10.0, Predicted class = 30.0
# Test sample 599: True class = 24.0, Predicted class = 13.0
# Test sample 600: True class = 1.0, Predicted class = 29.0
# Test sample 601: True class = 14.0, Predicted class = 35.0
# Test sample 602: True class = 13.0, Predicted class = 30.0
# Test sample 603: True class = 8.0, Predicted class = 31.0
# Test sample 604: True class = 23.0, Predicted class = 29.0
# Test sample 605: True class = 32.0, Predicted class = 13.0
# Test sample 606: True class = 31.0, Predicted class = 34.0
# Test sample 607: True class = 32.0, Predicted class = 5.0
# Test sample 608: True class = 10.0, Predicted class = 30.0
# Test sample 609: True class = 25.0, Predicted class = 28.0
# Test sample 610: True class = 14.0, Predicted class = 28.0
# Test sample 611: True class = 12.0, Predicted class = 7.0
# Test sample 612: True class = 6.0, Predicted class = 11.0
# Test sample 613: True class = 5.0, Predicted class = 30.0
# Test sample 614: True class = 4.0, Predicted class = 3.0
# Test sample 615: True class = 15.0, Predicted class = 10.0
# Test sample 616: True class = 11.0, Predicted class = 11.0
# Test sample 617: True class = 12.0, Predicted class = 5.0
# Test sample 618: True class = 1.0, Predicted class = 29.0
# Test sample 619: True class = 2.0, Predicted class = 22.0
# Test sample 620: True class = 5.0, Predicted class = 22.0
# Test sample 621: True class = 5.0, Predicted class = 32.0
# Test sample 622: True class = 30.0, Predicted class = 9.0
# Test sample 623: True class = 12.0, Predicted class = 32.0
# Test sample 624: True class = 8.0, Predicted class = 31.0
# Test sample 625: True class = 3.0, Predicted class = 13.0
# Test sample 626: True class = 15.0, Predicted class = 30.0
# Test sample 627: True class = 11.0, Predicted class = 9.0
# Test sample 628: True class = 24.0, Predicted class = 26.0
# Test sample 629: True class = 26.0, Predicted class = 32.0
# Test sample 630: True class = 36.0, Predicted class = 15.0
# Test sample 631: True class = 3.0, Predicted class = 24.0
# Test sample 632: True class = 7.0, Predicted class = 2.0
# Test sample 633: True class = 33.0, Predicted class = 12.0
# Test sample 634: True class = 7.0, Predicted class = 9.0
# Test sample 635: True class = 24.0, Predicted class = 1.0
# Test sample 636: True class = 28.0, Predicted class = 22.0
# Test sample 637: True class = 36.0, Predicted class = 15.0
# Test sample 638: True class = 11.0, Predicted class = 11.0
# Test sample 639: True class = 25.0, Predicted class = 9.0
# Test sample 640: True class = 15.0, Predicted class = 15.0
# Test sample 641: True class = 35.0, Predicted class = 12.0
# Test sample 642: True class = 7.0, Predicted class = 32.0
# Test sample 643: True class = 10.0, Predicted class = 4.0
# Test sample 644: True class = 11.0, Predicted class = 11.0
# Test sample 645: True class = 29.0, Predicted class = 26.0
# Test sample 646: True class = 14.0, Predicted class = 28.0
# Test sample 647: True class = 35.0, Predicted class = 32.0
# Test sample 648: True class = 24.0, Predicted class = 30.0
# Test sample 649: True class = 6.0, Predicted class = 9.0
# Test sample 650: True class = 27.0, Predicted class = 4.0
# Test sample 651: True class = 5.0, Predicted class = 7.0
# Test sample 652: True class = 1.0, Predicted class = 29.0
# Test sample 653: True class = 5.0, Predicted class = 7.0
# Test sample 654: True class = 29.0, Predicted class = 1.0
# Test sample 655: True class = 12.0, Predicted class = 14.0
# Test sample 656: True class = 12.0, Predicted class = 35.0
# Test sample 657: True class = 24.0, Predicted class = 4.0
# Test sample 658: True class = 33.0, Predicted class = 27.0
# Test sample 659: True class = 10.0, Predicted class = 9.0
# Test sample 660: True class = 8.0, Predicted class = 8.0
# Test sample 661: True class = 22.0, Predicted class = 32.0
# Test sample 662: True class = 27.0, Predicted class = 13.0
# Test sample 663: True class = 8.0, Predicted class = 8.0
# Test sample 664: True class = 1.0, Predicted class = 32.0
# Test sample 665: True class = 23.0, Predicted class = 23.0
# Test sample 666: True class = 36.0, Predicted class = 15.0
# Test sample 667: True class = 28.0, Predicted class = 25.0
# Test sample 668: True class = 14.0, Predicted class = 27.0
# Test sample 669: True class = 11.0, Predicted class = 6.0
# Test sample 670: True class = 3.0, Predicted class = 23.0
# Test sample 671: True class = 23.0, Predicted class = 29.0
# Test sample 672: True class = 36.0, Predicted class = 15.0
# Test sample 673: True class = 25.0, Predicted class = 10.0
# Test sample 674: True class = 35.0, Predicted class = 2.0
# Test sample 675: True class = 1.0, Predicted class = 33.0
# Test sample 676: True class = 36.0, Predicted class = 10.0
# Test sample 677: True class = 11.0, Predicted class = 11.0
# Test sample 678: True class = 8.0, Predicted class = 8.0
# Test sample 679: True class = 7.0, Predicted class = 9.0
# Test sample 680: True class = 2.0, Predicted class = 32.0
# Test sample 681: True class = 31.0, Predicted class = 34.0
# Test sample 682: True class = 32.0, Predicted class = 26.0
# Test sample 683: True class = 31.0, Predicted class = 34.0
# Test sample 684: True class = 2.0, Predicted class = 13.0
# Test sample 685: True class = 30.0, Predicted class = 9.0
# Test sample 686: True class = 13.0, Predicted class = 24.0
# Test sample 687: True class = 28.0, Predicted class = 14.0
# Test sample 688: True class = 33.0, Predicted class = 9.0
# Test sample 689: True class = 9.0, Predicted class = 24.0
# Test sample 690: True class = 27.0, Predicted class = 9.0
# Test sample 691: True class = 3.0, Predicted class = 4.0
# Test sample 692: True class = 13.0, Predicted class = 30.0
# Test sample 693: True class = 33.0, Predicted class = 13.0
# Test sample 694: True class = 34.0, Predicted class = 34.0
# Test sample 695: True class = 31.0, Predicted class = 34.0
# Test sample 696: True class = 11.0, Predicted class = 11.0
# Test sample 697: True class = 8.0, Predicted class = 8.0
# Test sample 698: True class = 14.0, Predicted class = 35.0
# Test sample 699: True class = 10.0, Predicted class = 9.0
# Test sample 700: True class = 30.0, Predicted class = 26.0
# Test sample 701: True class = 34.0, Predicted class = 34.0
# Test sample 702: True class = 13.0, Predicted class = 33.0
# Test sample 703: True class = 30.0, Predicted class = 27.0
# Test sample 704: True class = 36.0, Predicted class = 15.0
# Test sample 705: True class = 6.0, Predicted class = 23.0
# Test sample 706: True class = 2.0, Predicted class = 29.0
# Test sample 707: True class = 11.0, Predicted class = 11.0
# Test sample 708: True class = 4.0, Predicted class = 27.0
# Test sample 709: True class = 33.0, Predicted class = 30.0
# Test sample 710: True class = 23.0, Predicted class = 9.0
# Test sample 711: True class = 26.0, Predicted class = 9.0
# Test sample 712: True class = 3.0, Predicted class = 26.0
# Test sample 713: True class = 36.0, Predicted class = 11.0
# Test sample 714: True class = 28.0, Predicted class = 22.0
# Test sample 715: True class = 8.0, Predicted class = 8.0
# Test sample 716: True class = 30.0, Predicted class = 33.0
# Test sample 717: True class = 26.0, Predicted class = 1.0
# Test sample 718: True class = 32.0, Predicted class = 22.0
# Test sample 719: True class = 27.0, Predicted class = 33.0
# Test sample 720: True class = 28.0, Predicted class = 35.0
# Test sample 721: True class = 27.0, Predicted class = 33.0
# Test sample 722: True class = 14.0, Predicted class = 27.0
# Test sample 723: True class = 9.0, Predicted class = 30.0
# Test sample 724: True class = 27.0, Predicted class = 2.0
# Test sample 725: True class = 7.0, Predicted class = 5.0
# Test sample 726: True class = 7.0, Predicted class = 33.0
# Test sample 727: True class = 8.0, Predicted class = 8.0
# Test sample 728: True class = 9.0, Predicted class = 25.0
# Test sample 729: True class = 28.0, Predicted class = 12.0
# Test sample 730: True class = 32.0, Predicted class = 29.0
# Test sample 731: True class = 24.0, Predicted class = 33.0
# Test sample 732: True class = 6.0, Predicted class = 11.0
# Test sample 733: True class = 15.0, Predicted class = 10.0
# Test sample 734: True class = 10.0, Predicted class = 30.0
# Test sample 735: True class = 24.0, Predicted class = 13.0
# Test sample 736: True class = 1.0, Predicted class = 29.0
# Test sample 737: True class = 14.0, Predicted class = 35.0
# Test sample 738: True class = 13.0, Predicted class = 24.0
# Test sample 739: True class = 8.0, Predicted class = 31.0
# Test sample 740: True class = 23.0, Predicted class = 7.0
# Test sample 741: True class = 32.0, Predicted class = 13.0
# Test sample 742: True class = 31.0, Predicted class = 34.0
# Test sample 743: True class = 32.0, Predicted class = 27.0
# Test sample 744: True class = 10.0, Predicted class = 4.0
# Test sample 745: True class = 25.0, Predicted class = 28.0
# Test sample 746: True class = 14.0, Predicted class = 32.0
# Test sample 747: True class = 12.0, Predicted class = 7.0
# Test sample 748: True class = 6.0, Predicted class = 11.0
# Test sample 749: True class = 5.0, Predicted class = 30.0
# Test sample 750: True class = 4.0, Predicted class = 24.0
# Test sample 751: True class = 15.0, Predicted class = 10.0
# Test sample 752: True class = 11.0, Predicted class = 11.0
# Test sample 753: True class = 12.0, Predicted class = 5.0
# Test sample 754: True class = 1.0, Predicted class = 29.0
# Test sample 755: True class = 2.0, Predicted class = 22.0
# Test sample 756: True class = 5.0, Predicted class = 22.0
# Test sample 757: True class = 5.0, Predicted class = 32.0
# Test sample 758: True class = 30.0, Predicted class = 9.0
# Test sample 759: True class = 12.0, Predicted class = 32.0
# Test sample 760: True class = 8.0, Predicted class = 12.0
# Test sample 761: True class = 3.0, Predicted class = 27.0
# Test sample 762: True class = 15.0, Predicted class = 10.0
# Test sample 763: True class = 11.0, Predicted class = 9.0
# Test sample 764: True class = 24.0, Predicted class = 13.0
# Test sample 765: True class = 26.0, Predicted class = 22.0
# Test sample 766: True class = 36.0, Predicted class = 15.0
# Test sample 767: True class = 3.0, Predicted class = 24.0
# Test sample 768: True class = 7.0, Predicted class = 2.0
# Test sample 769: True class = 33.0, Predicted class = 27.0
# Test sample 770: True class = 7.0, Predicted class = 27.0
# Test sample 771: True class = 24.0, Predicted class = 1.0
# Test sample 772: True class = 28.0, Predicted class = 12.0
# Test sample 773: True class = 36.0, Predicted class = 15.0
# Test sample 774: True class = 11.0, Predicted class = 11.0
# Test sample 775: True class = 25.0, Predicted class = 9.0
# Test sample 776: True class = 15.0, Predicted class = 15.0
# Test sample 777: True class = 35.0, Predicted class = 12.0
# Test sample 778: True class = 7.0, Predicted class = 22.0
# Test sample 779: True class = 10.0, Predicted class = 4.0
# Test sample 780: True class = 11.0, Predicted class = 11.0
# Test sample 781: True class = 29.0, Predicted class = 26.0
# Test sample 782: True class = 14.0, Predicted class = 28.0
# Test sample 783: True class = 35.0, Predicted class = 28.0
# Test sample 784: True class = 24.0, Predicted class = 30.0
# Test sample 785: True class = 6.0, Predicted class = 6.0
# Test sample 786: True class = 27.0, Predicted class = 4.0
# Test sample 787: True class = 5.0, Predicted class = 7.0
# Test sample 788: True class = 1.0, Predicted class = 29.0
# Test sample 789: True class = 5.0, Predicted class = 7.0
# Test sample 790: True class = 29.0, Predicted class = 22.0
# Test sample 791: True class = 12.0, Predicted class = 35.0
# Test sample 792: True class = 12.0, Predicted class = 28.0
# Test sample 793: True class = 24.0, Predicted class = 4.0
# Test sample 794: True class = 33.0, Predicted class = 27.0
# Test sample 795: True class = 10.0, Predicted class = 9.0
# Test sample 796: True class = 8.0, Predicted class = 8.0
# Test sample 797: True class = 22.0, Predicted class = 32.0
# Test sample 798: True class = 27.0, Predicted class = 13.0
# Test sample 799: True class = 8.0, Predicted class = 8.0
# Test sample 800: True class = 1.0, Predicted class = 24.0
# Test sample 801: True class = 23.0, Predicted class = 23.0
# Test sample 802: True class = 36.0, Predicted class = 10.0
# Test sample 803: True class = 28.0, Predicted class = 25.0
# Test sample 804: True class = 14.0, Predicted class = 27.0
# Test sample 805: True class = 11.0, Predicted class = 6.0
# Test sample 806: True class = 3.0, Predicted class = 23.0
# Test sample 807: True class = 23.0, Predicted class = 9.0
# Test sample 808: True class = 36.0, Predicted class = 15.0
# Test sample 809: True class = 25.0, Predicted class = 10.0
# Test sample 810: True class = 35.0, Predicted class = 2.0
# Test sample 811: True class = 1.0, Predicted class = 33.0
# Test sample 812: True class = 36.0, Predicted class = 10.0
# Test sample 813: True class = 11.0, Predicted class = 11.0
# Test sample 814: True class = 8.0, Predicted class = 8.0
# Test sample 815: True class = 7.0, Predicted class = 9.0
# Test sample 816: True class = 2.0, Predicted class = 32.0
# Test sample 817: True class = 31.0, Predicted class = 34.0
# Test sample 818: True class = 32.0, Predicted class = 26.0
# Test sample 819: True class = 31.0, Predicted class = 34.0
# Test sample 820: True class = 2.0, Predicted class = 32.0
# Test sample 821: True class = 30.0, Predicted class = 25.0
# Test sample 822: True class = 13.0, Predicted class = 24.0
# Test sample 823: True class = 28.0, Predicted class = 14.0
# ...
# Test sample 1228: True class = 2.0, Predicted class = 32.0
# Test sample 1229: True class = 30.0, Predicted class = 9.0
# Test sample 1230: True class = 13.0, Predicted class = 24.0
# Test sample 1231: True class = 28.0, Predicted class = 14.0
# Test sample 1232: True class = 33.0, Predicted class = 3.0
# Test sample 1233: True class = 9.0, Predicted class = 26.0
# Test sample 1234: True class = 27.0, Predicted class = 9.0
# Test sample 1235: True class = 3.0, Predicted class = 26.0
# Test sample 1236: True class = 13.0, Predicted class = 30.0
# Test sample 1237: True class = 33.0, Predicted class = 13.0
# Test sample 1238: True class = 34.0, Predicted class = 34.0
# Test sample 1239: True class = 31.0, Predicted class = 34.0
# Test sample 1240: True class = 11.0, Predicted class = 11.0
# Test sample 1241: True class = 8.0, Predicted class = 8.0
# Test sample 1242: True class = 14.0, Predicted class = 28.0
# Test sample 1243: True class = 10.0, Predicted class = 9.0
# Test sample 1244: True class = 30.0, Predicted class = 3.0
# Test sample 1245: True class = 34.0, Predicted class = 34.0
# Test sample 1246: True class = 13.0, Predicted class = 33.0
# Test sample 1247: True class = 30.0, Predicted class = 27.0
# Test sample 1248: True class = 36.0, Predicted class = 15.0
# Test sample 1249: True class = 6.0, Predicted class = 23.0
# Test sample 1250: True class = 2.0, Predicted class = 27.0
# Test sample 1251: True class = 11.0, Predicted class = 11.0
# Test sample 1252: True class = 4.0, Predicted class = 27.0
# Test sample 1253: True class = 33.0, Predicted class = 28.0
# Test sample 1254: True class = 23.0, Predicted class = 9.0
# Test sample 1255: True class = 26.0, Predicted class = 27.0
# Test sample 1256: True class = 3.0, Predicted class = 13.0
# Test sample 1257: True class = 36.0, Predicted class = 11.0
# Test sample 1258: True class = 28.0, Predicted class = 22.0
# Test sample 1259: True class = 8.0, Predicted class = 8.0
# Test sample 1260: True class = 30.0, Predicted class = 33.0
# Test sample 1261: True class = 26.0, Predicted class = 1.0
# Test sample 1262: True class = 32.0, Predicted class = 1.0
# Test sample 1263: True class = 27.0, Predicted class = 33.0
# Test sample 1264: True class = 28.0, Predicted class = 35.0
# Test sample 1265: True class = 27.0, Predicted class = 26.0
# Test sample 1266: True class = 14.0, Predicted class = 35.0
# Test sample 1267: True class = 9.0, Predicted class = 30.0
# Test sample 1268: True class = 27.0, Predicted class = 2.0
# Test sample 1269: True class = 7.0, Predicted class = 5.0
# Test sample 1270: True class = 7.0, Predicted class = 32.0
# Test sample 1271: True class = 8.0, Predicted class = 8.0
# Test sample 1272: True class = 9.0, Predicted class = 4.0
# Test sample 1273: True class = 28.0, Predicted class = 12.0
# Test sample 1274: True class = 32.0, Predicted class = 29.0
# Test sample 1275: True class = 24.0, Predicted class = 33.0
# Test sample 1276: True class = 6.0, Predicted class = 11.0
# Test sample 1277: True class = 15.0, Predicted class = 10.0
# Test sample 1278: True class = 10.0, Predicted class = 30.0
# Test sample 1279: True class = 24.0, Predicted class = 13.0
# Test sample 1280: True class = 1.0, Predicted class = 29.0
# Test sample 1281: True class = 14.0, Predicted class = 35.0
# Test sample 1282: True class = 13.0, Predicted class = 24.0
# Test sample 1283: True class = 8.0, Predicted class = 31.0
# Test sample 1284: True class = 23.0, Predicted class = 4.0
# Test sample 1285: True class = 32.0, Predicted class = 22.0
# Test sample 1286: True class = 31.0, Predicted class = 34.0
# Test sample 1287: True class = 32.0, Predicted class = 27.0
# Test sample 1288: True class = 10.0, Predicted class = 30.0
# Test sample 1289: True class = 25.0, Predicted class = 4.0
# Test sample 1290: True class = 14.0, Predicted class = 32.0
# Test sample 1291: True class = 12.0, Predicted class = 7.0
# Test sample 1292: True class = 6.0, Predicted class = 11.0
# Test sample 1293: True class = 5.0, Predicted class = 30.0
# Test sample 1294: True class = 4.0, Predicted class = 24.0
# Test sample 1295: True class = 15.0, Predicted class = 10.0
# Test sample 1296: True class = 11.0, Predicted class = 11.0
# Test sample 1297: True class = 12.0, Predicted class = 5.0
# Test sample 1298: True class = 1.0, Predicted class = 29.0
# Test sample 1299: True class = 2.0, Predicted class = 22.0
# Test sample 1300: True class = 5.0, Predicted class = 22.0
# Test sample 1301: True class = 5.0, Predicted class = 32.0
# Test sample 1302: True class = 30.0, Predicted class = 9.0
# Test sample 1303: True class = 12.0, Predicted class = 32.0
# Test sample 1304: True class = 8.0, Predicted class = 31.0
# Test sample 1305: True class = 3.0, Predicted class = 13.0
# Test sample 1306: True class = 15.0, Predicted class = 10.0
# Test sample 1307: True class = 11.0, Predicted class = 9.0
# Test sample 1308: True class = 24.0, Predicted class = 26.0
# Test sample 1309: True class = 26.0, Predicted class = 32.0
# Test sample 1310: True class = 36.0, Predicted class = 15.0
# Test sample 1311: True class = 3.0, Predicted class = 13.0
# Test sample 1312: True class = 7.0, Predicted class = 1.0
# Test sample 1313: True class = 33.0, Predicted class = 12.0
# Test sample 1314: True class = 7.0, Predicted class = 32.0
# Test sample 1315: True class = 24.0, Predicted class = 1.0
# Test sample 1316: True class = 28.0, Predicted class = 12.0
# Test sample 1317: True class = 36.0, Predicted class = 15.0
# Test sample 1318: True class = 11.0, Predicted class = 11.0
# Test sample 1319: True class = 25.0, Predicted class = 9.0
# Test sample 1320: True class = 15.0, Predicted class = 15.0
# Test sample 1321: True class = 35.0, Predicted class = 14.0
# Test sample 1322: True class = 7.0, Predicted class = 32.0
# Test sample 1323: True class = 10.0, Predicted class = 4.0
# Test sample 1324: True class = 11.0, Predicted class = 11.0
# Test sample 1325: True class = 29.0, Predicted class = 22.0
# Test sample 1326: True class = 14.0, Predicted class = 28.0
# Test sample 1327: True class = 35.0, Predicted class = 32.0
# Test sample 1328: True class = 24.0, Predicted class = 30.0
# Test sample 1329: True class = 6.0, Predicted class = 9.0
# Test sample 1330: True class = 27.0, Predicted class = 4.0
# Test sample 1331: True class = 5.0, Predicted class = 7.0
# Test sample 1332: True class = 1.0, Predicted class = 29.0
# Test sample 1333: True class = 5.0, Predicted class = 7.0
# Test sample 1334: True class = 29.0, Predicted class = 1.0
# Test sample 1335: True class = 12.0, Predicted class = 35.0
# Test sample 1336: True class = 12.0, Predicted class = 35.0
# Test sample 1337: True class = 24.0, Predicted class = 4.0
# Test sample 1338: True class = 33.0, Predicted class = 27.0
# Test sample 1339: True class = 10.0, Predicted class = 9.0
# Test sample 1340: True class = 8.0, Predicted class = 8.0
# Test sample 1341: True class = 22.0, Predicted class = 32.0
# Test sample 1342: True class = 27.0, Predicted class = 1.0
# Test sample 1343: True class = 8.0, Predicted class = 8.0
# Test sample 1344: True class = 1.0, Predicted class = 32.0
# Test sample 1345: True class = 23.0, Predicted class = 23.0
# Test sample 1346: True class = 36.0, Predicted class = 10.0
# Test sample 1347: True class = 28.0, Predicted class = 25.0
# Test sample 1348: True class = 14.0, Predicted class = 27.0
# Test sample 1349: True class = 11.0, Predicted class = 6.0
# Test sample 1350: True class = 3.0, Predicted class = 1.0
# Test sample 1351: True class = 23.0, Predicted class = 9.0
# Test sample 1352: True class = 36.0, Predicted class = 15.0
# Test sample 1353: True class = 25.0, Predicted class = 10.0
# Test sample 1354: True class = 35.0, Predicted class = 25.0
# Test sample 1355: True class = 1.0, Predicted class = 33.0
# Test sample 1356: True class = 36.0, Predicted class = 10.0
# Test sample 1357: True class = 11.0, Predicted class = 11.0
# Test sample 1358: True class = 8.0, Predicted class = 8.0
# Test sample 1359: True class = 7.0, Predicted class = 9.0
# Test sample 1360: True class = 2.0, Predicted class = 32.0
# Test sample 1361: True class = 31.0, Predicted class = 34.0
# Test sample 1362: True class = 32.0, Predicted class = 26.0
# Test sample 1363: True class = 31.0, Predicted class = 34.0
# Test sample 1364: True class = 2.0, Predicted class = 32.0
# Test sample 1365: True class = 30.0, Predicted class = 9.0
# Test sample 1366: True class = 13.0, Predicted class = 3.0
# Test sample 1367: True class = 28.0, Predicted class = 14.0
# Test sample 1368: True class = 33.0, Predicted class = 30.0
# Test sample 1369: True class = 9.0, Predicted class = 26.0
# Test sample 1370: True class = 27.0, Predicted class = 9.0
# Test sample 1371: True class = 3.0, Predicted class = 26.0
# Test sample 1372: True class = 13.0, Predicted class = 30.0
# Test sample 1373: True class = 33.0, Predicted class = 13.0
# Test sample 1374: True class = 34.0, Predicted class = 34.0
# Test sample 1375: True class = 31.0, Predicted class = 34.0
# Test sample 1376: True class = 11.0, Predicted class = 11.0
# Test sample 1377: True class = 8.0, Predicted class = 8.0
# Test sample 1378: True class = 14.0, Predicted class = 28.0
# Test sample 1379: True class = 10.0, Predicted class = 9.0
# Test sample 1380: True class = 30.0, Predicted class = 26.0
# Test sample 1381: True class = 34.0, Predicted class = 34.0
# Test sample 1382: True class = 13.0, Predicted class = 33.0
# Test sample 1383: True class = 30.0, Predicted class = 33.0
# Test sample 1384: True class = 36.0, Predicted class = 15.0
# Test sample 1385: True class = 6.0, Predicted class = 23.0
# Test sample 1386: True class = 2.0, Predicted class = 27.0
# Test sample 1387: True class = 11.0, Predicted class = 11.0
# Test sample 1388: True class = 4.0, Predicted class = 3.0
# Test sample 1389: True class = 33.0, Predicted class = 28.0
# Test sample 1390: True class = 23.0, Predicted class = 24.0
# Test sample 1391: True class = 26.0, Predicted class = 3.0
# Test sample 1392: True class = 3.0, Predicted class = 13.0
# Test sample 1393: True class = 36.0, Predicted class = 11.0
# Test sample 1394: True class = 28.0, Predicted class = 22.0
# Test sample 1395: True class = 8.0, Predicted class = 8.0
# Test sample 1396: True class = 30.0, Predicted class = 10.0
# Test sample 1397: True class = 26.0, Predicted class = 22.0
# Test sample 1398: True class = 32.0, Predicted class = 22.0
# Test sample 1399: True class = 27.0, Predicted class = 33.0
# Test sample 1400: True class = 28.0, Predicted class = 35.0
# Test sample 1401: True class = 27.0, Predicted class = 26.0
# Test sample 1402: True class = 14.0, Predicted class = 27.0
# Test sample 1403: True class = 9.0, Predicted class = 30.0
# Test sample 1404: True class = 27.0, Predicted class = 13.0
# Test sample 1405: True class = 7.0, Predicted class = 5.0
# Test sample 1406: True class = 7.0, Predicted class = 33.0
# Test sample 1407: True class = 8.0, Predicted class = 8.0
# Test sample 1408: True class = 9.0, Predicted class = 25.0
# Test sample 1409: True class = 28.0, Predicted class = 12.0
# Test sample 1410: True class = 32.0, Predicted class = 29.0
# Test sample 1411: True class = 24.0, Predicted class = 33.0
# Test sample 1412: True class = 6.0, Predicted class = 11.0
# Test sample 1413: True class = 15.0, Predicted class = 10.0
# Test sample 1414: True class = 10.0, Predicted class = 30.0
# Test sample 1415: True class = 24.0, Predicted class = 13.0
# Test sample 1416: True class = 1.0, Predicted class = 29.0
# Test sample 1417: True class = 14.0, Predicted class = 35.0
# Test sample 1418: True class = 13.0, Predicted class = 24.0
# Test sample 1419: True class = 8.0, Predicted class = 31.0
# Test sample 1420: True class = 23.0, Predicted class = 4.0
# Test sample 1421: True class = 32.0, Predicted class = 22.0
# Test sample 1422: True class = 31.0, Predicted class = 34.0
# Test sample 1423: True class = 32.0, Predicted class = 27.0
# Test sample 1424: True class = 10.0, Predicted class = 30.0
# Test sample 1425: True class = 25.0, Predicted class = 28.0
# Test sample 1426: True class = 14.0, Predicted class = 32.0
# Test sample 1427: True class = 12.0, Predicted class = 4.0
# Test sample 1428: True class = 6.0, Predicted class = 11.0
# Test sample 1429: True class = 5.0, Predicted class = 30.0
# Test sample 1430: True class = 4.0, Predicted class = 24.0
# Test sample 1431: True class = 15.0, Predicted class = 10.0
# Test sample 1432: True class = 11.0, Predicted class = 11.0
# Test sample 1433: True class = 12.0, Predicted class = 28.0
# Test sample 1434: True class = 1.0, Predicted class = 29.0
# Test sample 1435: True class = 2.0, Predicted class = 22.0
# Test sample 1436: True class = 5.0, Predicted class = 22.0
# Test sample 1437: True class = 5.0, Predicted class = 25.0
# Test sample 1438: True class = 30.0, Predicted class = 9.0
# Test sample 1439: True class = 12.0, Predicted class = 32.0
# Test sample 1440: True class = 8.0, Predicted class = 12.0
# Test sample 1441: True class = 3.0, Predicted class = 27.0
# Test sample 1442: True class = 15.0, Predicted class = 10.0
# Test sample 1443: True class = 11.0, Predicted class = 9.0
# Test sample 1444: True class = 24.0, Predicted class = 26.0
# Test sample 1445: True class = 26.0, Predicted class = 32.0
# Test sample 1446: True class = 36.0, Predicted class = 15.0
# Test sample 1447: True class = 3.0, Predicted class = 24.0
# Test sample 1448: True class = 7.0, Predicted class = 32.0
# Test sample 1449: True class = 33.0, Predicted class = 25.0
# Test sample 1450: True class = 7.0, Predicted class = 32.0
# Test sample 1451: True class = 24.0, Predicted class = 1.0
# Test sample 1452: True class = 28.0, Predicted class = 12.0
# Test sample 1453: True class = 36.0, Predicted class = 15.0
# Test sample 1454: True class = 11.0, Predicted class = 11.0
# Test sample 1455: True class = 25.0, Predicted class = 3.0
# Test sample 1456: True class = 15.0, Predicted class = 15.0
# Test sample 1457: True class = 35.0, Predicted class = 14.0
# Test sample 1458: True class = 7.0, Predicted class = 32.0
# Test sample 1459: True class = 10.0, Predicted class = 4.0
# Test sample 1460: True class = 11.0, Predicted class = 11.0
# Test sample 1461: True class = 29.0, Predicted class = 26.0
# Test sample 1462: True class = 14.0, Predicted class = 28.0
# Test sample 1463: True class = 35.0, Predicted class = 28.0
# Test sample 1464: True class = 24.0, Predicted class = 30.0
# Test sample 1465: True class = 6.0, Predicted class = 15.0
# Test sample 1466: True class = 27.0, Predicted class = 4.0
# Test sample 1467: True class = 5.0, Predicted class = 22.0
# Test sample 1468: True class = 1.0, Predicted class = 29.0
# Test sample 1469: True class = 5.0, Predicted class = 7.0
# Test sample 1470: True class = 29.0, Predicted class = 22.0
# Test sample 1471: True class = 12.0, Predicted class = 14.0
# Test sample 1472: True class = 12.0, Predicted class = 28.0
# Test sample 1473: True class = 24.0, Predicted class = 4.0
# Test sample 1474: True class = 33.0, Predicted class = 13.0
# Test sample 1475: True class = 10.0, Predicted class = 9.0
# Test sample 1476: True class = 8.0, Predicted class = 8.0
# Test sample 1477: True class = 22.0, Predicted class = 32.0
# Test sample 1478: True class = 27.0, Predicted class = 4.0
# Test sample 1479: True class = 8.0, Predicted class = 8.0
# Test sample 1480: True class = 1.0, Predicted class = 32.0
# Test sample 1481: True class = 23.0, Predicted class = 23.0
# Test sample 1482: True class = 36.0, Predicted class = 10.0
# Test sample 1483: True class = 28.0, Predicted class = 35.0
# Test sample 1484: True class = 14.0, Predicted class = 27.0
# Test sample 1485: True class = 11.0, Predicted class = 6.0
# Test sample 1486: True class = 3.0, Predicted class = 1.0
# Test sample 1487: True class = 23.0, Predicted class = 29.0
# Test sample 1488: True class = 36.0, Predicted class = 15.0
# Test sample 1489: True class = 25.0, Predicted class = 10.0
# Test sample 1490: True class = 35.0, Predicted class = 2.0
# Test sample 1491: True class = 1.0, Predicted class = 33.0
# Test sample 1492: True class = 36.0, Predicted class = 10.0
# Test sample 1493: True class = 11.0, Predicted class = 11.0
# Test sample 1494: True class = 8.0, Predicted class = 8.0
# Test sample 1495: True class = 7.0, Predicted class = 27.0
# Test sample 1496: True class = 2.0, Predicted class = 32.0

# %% [markdown]
# ### Zadanie 7
# Przeprowadź klasyfikację liści wybranych wcześniej (dwóch) klas korzystając z własnej implementacji modelu kNN, a następnie wyświetl wyniki klasyfikacji (próbki treningowe i testowe), każdą klasę w innym kolorze, a próbki testowe innym "markerem".
#
# > Wykorzystaj parametry: `facecolors`, `edgecolors`, `marker` i `c` funkcji `scatter`.

# %%
import numpy as np
import matplotlib.pyplot as plt

with open('./dataset/dataset.npz', 'rb') as f:
    data = np.load(f)
    train, test = data['train'], data['test']

def euclidean_distance(vec1, vec2):
    return np.sqrt(np.sum((vec1 - vec2) ** 2))

def knn_classifier(train, test, k=3):
    predicted_classes = []
    for test_sample in test:
        test_features = test_sample[1:]

        distances = []
        for train_sample in train:
            train_features = train_sample[1:]
            distance = euclidean_distance(test_features, train_features)
            distances.append((distance, train_sample[0]))

        nearest_neighbors = sorted(distances, key=lambda x: x[0])[:k]
        nearest_neighbors_classes = [neighbor[1] for neighbor in nearest_neighbors]
        
        predicted_class = max(nearest_neighbors_classes, key=nearest_neighbors_classes.count)
        predicted_classes.append(predicted_class)
    
    return np.array(predicted_classes)

# wybrane klasy: 3 - Populus nigra, 5 - Quercus robur
train_class3 = train[train[:, 0] == 3]
train_class5 = train[train[:, 0] == 5]
test_class3 = test[test[:, 0] == 3]
test_class5 = test[test[:, 0] == 5]

train_data = np.concatenate([train_class3, train_class5], axis=0)
test_data = np.concatenate([test_class3, test_class5], axis=0)

predicted_classes = knn_classifier(train_data, test_data, k=3)

plt.scatter(train_class3[:, 4], train_class3[:, 8],  marker='o', label='Klasa 3 - treningowa', facecolors='none', edgecolors='blue')
plt.scatter(train_class5[:, 4], train_class5[:, 8], marker='o', label='Klasa 5 - treningowa', facecolors='none', edgecolors='red')

plt.scatter(test_data[:, 4], test_data[:, 8], c=predicted_classes, cmap='coolwarm', marker='x', label='Klasa testowa')

plt.xlabel('Cecha 4')
plt.ylabel('Cecha 8')
plt.title('kNN - Klasyfikacja')
plt.legend()
plt.show()

# %% [markdown]
# ### Zadanie 8
#
# Oblicz dokładność (*Accuracy*) klasyfikacji (stosunek poprawnie zaklasyfikowanych próbek do liczby wszystkich próbek wyrażony procentowo).
#
# $$
# \texttt{Accuracy} = \frac{T}{N}
# $$
#
# gdzie $T$ - liczba poprawnie zaklasyfikowanych próbek, $N$ - liczba wszystkich próbek.

# %%
true_classes = test_data[:, 0]
correctly_classified = (true_classes == predicted_classes).sum()
total_samples = len(test_data)
accuracy = (correctly_classified / total_samples) * 100 
print(f"Accuracy: {accuracy:.2f}%")
# Out:
# Accuracy: 42.73%

# %% [markdown]
# ### Zadanie 9
#
# Wybierz 5 dowolnych rodzajów liści (klasy) i przeprowadź eksperyment ponownie.

# %%
train_class1 = train[train[:, 0] == 1]
train_class2 = train[train[:, 0] == 2]
train_class3 = train[train[:, 0] == 3]
train_class4 = train[train[:, 0] == 4]
train_class5 = train[train[:, 0] == 5]

test_class1 = test[test[:, 0] == 1]
test_class2 = test[test[:, 0] == 2]
test_class3 = test[test[:, 0] == 3]
test_class4 = test[test[:, 0] == 4]
test_class5 = test[test[:, 0] == 5]

train_data = np.concatenate([train_class1, train_class2, train_class3, train_class4, train_class5], axis=0)
test_data = np.concatenate([test_class1, test_class2, test_class3, test_class4, test_class5], axis=0)

predicted_classes = knn_classifier(train_data, test_data, k=3)

colors = {1: 'blue', 2: 'red', 3: 'green', 4: 'purple', 5: 'orange'}

plt.scatter(train_class1[:, 4], train_class1[:, 8], c='blue', marker='o', label='Klasa 1 - treningowa', facecolors='none', edgecolors='blue')
plt.scatter(train_class2[:, 4], train_class2[:, 8], c='red', marker='o', label='Klasa 2 - treningowa', facecolors='none', edgecolors='red')
plt.scatter(train_class3[:, 4], train_class3[:, 8], c='green', marker='o', label='Klasa 3 - treningowa', facecolors='none', edgecolors='green')
plt.scatter(train_class4[:, 4], train_class4[:, 8], c='purple', marker='o', label='Klasa 4 - treningowa', facecolors='none', edgecolors='purple')
plt.scatter(train_class5[:, 4], train_class5[:, 8], c='orange', marker='o', label='Klasa 5 - treningowa', facecolors='none', edgecolors='orange')

# plt.scatter(test_data[:, 4], test_data[:, 8], c=predicted_classes, cmap='coolwarm', marker='x', label='Dane testowe')
for i, test_sample in enumerate(test_data):
    predicted_class = predicted_classes[i]
    plt.scatter(test_sample[4], test_sample[8], c=colors[predicted_class], marker='x', label=f'Dane testowe' if i == 0 else "")

plt.xlabel('Cecha 4')
plt.ylabel('Cecha 8')
plt.title('kNN Klasyfikacja')
plt.legend()
plt.show()

# %% [markdown]
# ### Zadanie 10
#
# Przeprowadź eksperyment ponownie dla takich samych parametrów jak w zad. 9, ale większej losowo wybranej liczby cech: 3, 5, 10.
#
# > W tym przypadku nie wyświetlaj wykresu a jedynie oblicz dokładność klasyfikacji.

# %%
num_features = random.choice([3, 5, 10])
print(f"Losowo wybrana liczba cech: {num_features}")

train_class1 = train[train[:, 0] == 1]
train_class2 = train[train[:, 0] == 2]
train_class3 = train[train[:, 0] == 3]
train_class4 = train[train[:, 0] == 4]
train_class5 = train[train[:, 0] == 5]

test_class1 = test[test[:, 0] == 1]
test_class2 = test[test[:, 0] == 2]
test_class3 = test[test[:, 0] == 3]
test_class4 = test[test[:, 0] == 4]
test_class5 = test[test[:, 0] == 5]

train_data = np.concatenate([train_class1, train_class2, train_class3, train_class4, train_class5], axis=0)
test_data = np.concatenate([test_class1, test_class2, test_class3, test_class4, test_class5], axis=0)

def calculate_accuracy(true_classes, predicted_classes):
    correct = np.sum(true_classes == predicted_classes)
    accuracy = (correct / len(true_classes)) * 100
    return accuracy

train_features = train_data[:, 1:num_features+1]
test_features = test_data[:, 1:num_features+1]

predicted_classes = knn_classifier(train_features, test_features, k=3)

true_classes = test_data[:, 0]
accuracy = calculate_accuracy(true_classes, predicted_classes)

print(f"Dokładność dla {num_features} cech: {accuracy:.2f}%")
# Out:
# Losowo wybrana liczba cech: 5
# Dokładność dla 5 cech: 13.42%

# %% [markdown]
# ### Zadanie 11
#
# Napisz wnioski z przeprowadzonego eksperymentu.

# %%
"""
Eksperyment pokazał, że dokładność klasyfikacji jest mocno zależna od liczby cech wykorzystywanych do procesu klasyfikacji.
Zwiększenie liczby cech do 10 (największa liczba dostępna w eksperymencie) nie przyniosło znaczącej poprawy, 
ponieważ dokładność wyniosła tylko 15.15%
"""
